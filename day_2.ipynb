# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# plot below

# %%
# %matplotlib inline
x = np.linspace(1, 10, 100)
y = np.sin(x)
y2 = np.cos(y)
y3 = np.cos(x)

plt.plot(x, y);
plt.plot(x, y2);
plt.plot(x, y3)
